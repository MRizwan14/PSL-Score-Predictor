# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('psl_dataset_2.pkl','rb'))

# %%
df
#required features
# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current run rate
# last five
# Out:
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#     player_dismissed city                                venue
# 0    Mohammad Hafeez  NaN  Dubai International Cricket Stadium
# 1                  0  NaN  Dubai International Cricket Stadium
# 2                  0  NaN  Dubai International Cricket Stadium
# 3                  0  NaN  Dubai International Cricket Stadium
# 4                  0  NaN  Dubai International Cricket Stadium
# ..               ...  ...                                  ...
# 115                0  NaN  Dubai International Cricket Stadium
# 116                0  NaN  Dubai International Cricket Stadium
# 117        Anwar Ali  NaN  Dubai International Cricket Stadium
# 118                0  NaN  Dubai International Cricket Stadium
# 119                0  NaN  Dubai International Cricket Stadium
#
# [17327 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                5498
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium    3370
# Sharjah Cricket Stadium                2128
# Name: venue, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df['city'].value_counts()
# Out:
# Dubai         7129
# Sharjah       4561
# Karachi       2586
# Lahore        1560
# Rawalpindi     628
# Abu Dhabi      499
# Multan         364
# Name: city, dtype: int64

# %%
#cities where a minimum of 5 matches have been played
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
eligible_cities
# Out:
# ['Dubai', 'Sharjah', 'Karachi', 'Lahore', 'Rawalpindi']

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#     player_dismissed   city
# 0    Mohammad Hafeez  Dubai
# 1                  0  Dubai
# 2                  0  Dubai
# 3                  0  Dubai
# 4                  0  Dubai
# ..               ...    ...
# 115                0  Dubai
# 116                0  Dubai
# 117        Anwar Ali  Dubai
# 118                0  Dubai
# 119                0  Dubai
#
# [16464 rows x 7 columns]

# %%
#using cumulative sum to find the current score
df['current_score'] = df.groupby('match_id').cumsum()['runs']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\774859957.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id').cumsum()['runs']

# %%
df
# Out:
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#     player_dismissed   city  current_score
# 0    Mohammad Hafeez  Dubai              0
# 1                  0  Dubai              1
# 2                  0  Dubai              1
# 3                  0  Dubai              1
# 4                  0  Dubai              1
# ..               ...    ...            ...
# 115                0  Dubai            166
# 116                0  Dubai            168
# 117        Anwar Ali  Dubai            168
# 118                0  Dubai            168
# 119                0  Dubai            174
#
# [16464 rows x 8 columns]

# %%
#splitting ball column to get over and ball no
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\648357512.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\648357512.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#     player_dismissed   city  current_score over ball_no
# 0    Mohammad Hafeez  Dubai              0    0       1
# 1                  0  Dubai              1    0       2
# 2                  0  Dubai              1    0       3
# 3                  0  Dubai              1    0       4
# 4                  0  Dubai              1    0       5
# ..               ...    ...            ...  ...     ...
# 115                0  Dubai            166   19       2
# 116                0  Dubai            168   19       3
# 117        Anwar Ali  Dubai            168   19       4
# 118                0  Dubai            168   19       5
# 119                0  Dubai            174   19       6
#
# [16464 rows x 10 columns]

# %%
df
# Out:
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#     player_dismissed   city  current_score over ball_no
# 0    Mohammad Hafeez  Dubai              0    0       1
# 1                  0  Dubai              1    0       2
# 2                  0  Dubai              1    0       3
# 3                  0  Dubai              1    0       4
# 4                  0  Dubai              1    0       5
# ..               ...    ...            ...  ...     ...
# 115                0  Dubai            166   19       2
# 116                0  Dubai            168   19       3
# 117        Anwar Ali  Dubai            168   19       4
# 118                0  Dubai            168   19       5
# 119                0  Dubai            174   19       6
#
# [16464 rows x 10 columns]

# %%
#balls bowled
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\1081030914.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#     player_dismissed   city  current_score over ball_no  balls_bowled
# 0    Mohammad Hafeez  Dubai              0    0       1             1
# 1                  0  Dubai              1    0       2             2
# 2                  0  Dubai              1    0       3             3
# 3                  0  Dubai              1    0       4             4
# 4                  0  Dubai              1    0       5             5
# ..               ...    ...            ...  ...     ...           ...
# 115                0  Dubai            166   19       2           116
# 116                0  Dubai            168   19       3           117
# 117        Anwar Ali  Dubai            168   19       4           118
# 118                0  Dubai            168   19       5           119
# 119                0  Dubai            174   19       6           120
#
# [16464 rows x 11 columns]

# %%
#wickets left
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\286582229.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\286582229.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\286582229.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\286582229.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#      player_dismissed   city  current_score over ball_no  balls_bowled  \
# 0                   1  Dubai              0    0       1             1
# 1                   1  Dubai              1    0       2             2
# 2                   1  Dubai              1    0       3             3
# 3                   1  Dubai              1    0       4             4
# 4                   1  Dubai              1    0       5             5
# ..                ...    ...            ...  ...     ...           ...
# 115                 6  Dubai            166   19       2           116
# 116                 6  Dubai            168   19       3           117
# 117                 7  Dubai            168   19       4           118
# 118                 7  Dubai            168   19       5           119
# 119                 7  Dubai            174   19       6           120
#
#      wickets_left
# 0               9
# 1               9
# 2               9
# 3               9
# 4               9
# ..            ...
# 115             4
# 116             4
# 117             3
# 118             3
# 119             3
#
# [16464 rows x 12 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#      player_dismissed   city  current_score over ball_no  balls_bowled  \
# 0                   1  Dubai              0    0       1             1
# 1                   1  Dubai              1    0       2             2
# 2                   1  Dubai              1    0       3             3
# 3                   1  Dubai              1    0       4             4
# 4                   1  Dubai              1    0       5             5
# ..                ...    ...            ...  ...     ...           ...
# 115                 6  Dubai            166   19       2           116
# 116                 6  Dubai            168   19       3           117
# 117                 7  Dubai            168   19       4           118
# 118                 7  Dubai            168   19       5           119
# 119                 7  Dubai            174   19       6           120
#
#      wickets_left       crr
# 0               9  0.000000
# 1               9  3.000000
# 2               9  2.000000
# 3               9  1.500000
# 4               9  1.200000
# ..            ...       ...
# 115             4  8.586207
# 116             4  8.615385
# 117             3  8.542373
# 118             3  8.470588
# 119             3  8.700000
#
# [16464 rows x 13 columns]

# %%
#score in last 5 overs
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
df['last_five'] = last_five
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14680\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df
# Out:
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#      player_dismissed   city  current_score over ball_no  balls_bowled  \
# 0                   1  Dubai              0    0       1             1
# 1                   1  Dubai              1    0       2             2
# 2                   1  Dubai              1    0       3             3
# 3                   1  Dubai              1    0       4             4
# 4                   1  Dubai              1    0       5             5
# ..                ...    ...            ...  ...     ...           ...
# 115                 6  Dubai            166   19       2           116
# 116                 6  Dubai            168   19       3           117
# 117                 7  Dubai            168   19       4           118
# 118                 7  Dubai            168   19       5           119
# 119                 7  Dubai            174   19       6           120
#
#      wickets_left       crr  last_five
# 0               9  0.000000        NaN
# 1               9  3.000000        NaN
# 2               9  2.000000        NaN
# 3               9  1.500000        NaN
# 4               9  1.200000        NaN
# ..            ...       ...        ...
# 115             4  8.586207       46.0
# 116             4  8.615385       48.0
# 117             3  8.542373       47.0
# 118             3  8.470588       43.0
# 119             3  8.700000       45.0
#
# [16464 rows x 14 columns]

# %%
#total runs
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','wickets_left','crr','last_five','runs_x']]

# %%
final_df
# Out:
#             batting_team      bowling_team   city  current_score  \
# 0         Peshawar Zalmi  Islamabad United  Dubai              0
# 1         Peshawar Zalmi  Islamabad United  Dubai              1
# 2         Peshawar Zalmi  Islamabad United  Dubai              1
# 3         Peshawar Zalmi  Islamabad United  Dubai              1
# 4         Peshawar Zalmi  Islamabad United  Dubai              1
# ...                  ...               ...    ...            ...
# 16459  Quetta Gladiators  Islamabad United  Dubai            166
# 16460  Quetta Gladiators  Islamabad United  Dubai            168
# 16461  Quetta Gladiators  Islamabad United  Dubai            168
# 16462  Quetta Gladiators  Islamabad United  Dubai            168
# 16463  Quetta Gladiators  Islamabad United  Dubai            174
#
#        wickets_left       crr  last_five  runs_x
# 0                 9  0.000000        NaN     190
# 1                 9  3.000000        NaN     190
# 2                 9  2.000000        NaN     190
# 3                 9  1.500000        NaN     190
# 4                 9  1.200000        NaN     190
# ...             ...       ...        ...     ...
# 16459             4  8.586207       46.0     174
# 16460             4  8.615385       48.0     174
# 16461             3  8.542373       47.0     174
# 16462             3  8.470588       43.0     174
# 16463             3  8.700000       45.0     174
#
# [16464 rows x 8 columns]

# %%
final_df.isnull().sum()
# Out:
# batting_team        0
# bowling_team        0
# city                0
# current_score       0
# wickets_left        0
# crr                 0
# last_five        3973
# runs_x              0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
final_df
# Out:
#             batting_team      bowling_team   city  current_score  \
# 29        Peshawar Zalmi  Islamabad United  Dubai             41
# 30        Peshawar Zalmi  Islamabad United  Dubai             45
# 31        Peshawar Zalmi  Islamabad United  Dubai             46
# 32        Peshawar Zalmi  Islamabad United  Dubai             50
# 33        Peshawar Zalmi  Islamabad United  Dubai             50
# ...                  ...               ...    ...            ...
# 16459  Quetta Gladiators  Islamabad United  Dubai            166
# 16460  Quetta Gladiators  Islamabad United  Dubai            168
# 16461  Quetta Gladiators  Islamabad United  Dubai            168
# 16462  Quetta Gladiators  Islamabad United  Dubai            168
# 16463  Quetta Gladiators  Islamabad United  Dubai            174
#
#        wickets_left       crr  last_five  runs_x
# 29                9  8.200000       41.0     190
# 30                9  8.709677       45.0     190
# 31                9  8.625000       45.0     190
# 32                9  9.090909       49.0     190
# 33                9  8.823529       49.0     190
# ...             ...       ...        ...     ...
# 16459             4  8.586207       46.0     174
# 16460             4  8.615385       48.0     174
# 16461             3  8.542373       47.0     174
# 16462             3  8.470588       43.0     174
# 16463             3  8.700000       45.0     174
#
# [12491 rows x 8 columns]

# %%
#shuffling to avoid bias
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.head()
# Out:
#            batting_team       bowling_team     city  current_score  \
# 13102     Karachi Kings  Quetta Gladiators  Karachi             80
# 1062   Islamabad United      Karachi Kings  Sharjah             34
# 2864     Peshawar Zalmi     Multan Sultans    Dubai             62
# 15676  Lahore Qalandars  Quetta Gladiators    Dubai            116
# 6544     Peshawar Zalmi  Quetta Gladiators   Lahore            125
#
#        wickets_left       crr  last_five  runs_x
# 13102             7  6.075949       29.0     150
# 1062              8  4.975610       26.0      90
# 2864              7  5.552239       33.0     151
# 15676             9  9.666667       51.0     201
# 6544              4  7.500000       40.0     157

# %% [markdown]
# # Model Training

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#            batting_team       bowling_team        city  current_score  \
# 13839  Lahore Qalandars      Karachi Kings       Dubai             75
# 3817   Islamabad United  Quetta Gladiators     Sharjah             52
# 10622  Lahore Qalandars     Multan Sultans      Lahore             79
# 1330     Peshawar Zalmi   Islamabad United     Sharjah            117
# 4572     Multan Sultans     Peshawar Zalmi       Dubai            109
# ...                 ...                ...         ...            ...
# 10868    Multan Sultans   Islamabad United      Lahore             70
# 4670     Multan Sultans  Quetta Gladiators       Dubai             63
# 1756     Peshawar Zalmi   Lahore Qalandars       Dubai             48
# 12030  Islamabad United     Peshawar Zalmi  Rawalpindi            103
# 12008  Islamabad United     Peshawar Zalmi  Rawalpindi             60
#
#        wickets_left        crr  last_five
# 13839             7   5.696203       28.0
# 3817              8   8.666667       44.0
# 10622             7   8.777778       38.0
# 1330              3   6.815534       42.0
# 4572              8   7.517241       48.0
# ...             ...        ...        ...
# 10868             7   7.368421       48.0
# 4670              7   6.196721       33.0
# 1756              9   8.228571       42.0
# 12030             8  10.474576       56.0
# 12008             8   9.729730       45.0
#
# [9992 rows x 7 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
#random forest
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',RandomForestRegressor(n_estimators=300, random_state=101))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9736277733750389
# 1.9505858343337334

# %%
pickle.dump(pipe,open('psl.pkl','wb'))

# %%
# svm regressor
# from sklearn.svm import SVR

# %%
# pipe_svm = Pipeline(steps=[
#     ('step1',trf),
#     ('step2',StandardScaler()),
#     ('step3',SVR(kernel='rbf'))
# ])

# %%
# pipe_svm.fit(X_train,y_train)
# y_pred_svm = pipe_svm.predict(X_test)
# print(r2_score(y_test,y_pred_svm))
# print(mean_absolute_error(y_test,y_pred_svm))
# Out:
# 0.7827804452965735
# 8.336215149889107

# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames[0:5]
# Out:
# ['data\\1075986.yaml',
#  'data\\1075987.yaml',
#  'data\\1075988.yaml',
#  'data\\1075989.yaml',
#  'data\\1075990.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = final_df.append(df)
        counter+=1
        
final_df
# Out:
#  99%|██████████████████████████████████████████████████████████████████████████████▉ | 146/148 [00:53<00:00,  2.74it/s]
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [50], in <cell line: 3>()
#       3 for file in tqdm(filenames):
#       4     with open(file, 'r') as f:
# ----> 5         df = pd.json_normalize(safe_load(f))
#       6         df['match_id'] = counter
#       7         final_df = final_df.append(df)
#
# File E:\python\lib\site-packages\yaml\__init__.py:125, in safe_load(stream)
#     117 def safe_load(stream):
#     118     """
#     119     Parse the first YAML document in a stream
#     120     and produce the corresponding Python object.
#    (...)
#     123     to be safe for untrusted input.
#     124     """
# --> 125     return load(stream, SafeLoader)
#
# File E:\python\lib\site-packages\yaml\__init__.py:81, in load(stream, Loader)
#      79 loader = Loader(stream)
#      80 try:
# ---> 81     return loader.get_single_data()
#      82 finally:
#      83     loader.dispose()
#
# File E:\python\lib\site-packages\yaml\constructor.py:49, in BaseConstructor.get_single_data(self)
#      47 def get_single_data(self):
#      48     # Ensure that the stream contains a single document and construct it.
# ---> 49     node = self.get_single_node()
#      50     if node is not None:
#      51         return self.construct_document(node)
#
# File E:\python\lib\site-packages\yaml\composer.py:39, in Composer.get_single_node(self)
#      36     document = self.compose_document()
#      38 # Ensure that the stream contains no more documents.
# ---> 39 if not self.check_event(StreamEndEvent):
#      40     event = self.get_event()
#      41     raise ComposerError("expected a single document in the stream",
#      42             document.start_mark, "but found another document",
#      43             event.start_mark)
#
# File E:\python\lib\site-packages\yaml\parser.py:98, in Parser.check_event(self, *choices)
#      96 if self.current_event is None:
#      97     if self.state:
# ---> 98         self.current_event = self.state()
#      99 if self.current_event is not None:
#     100     if not choices:
#
# File E:\python\lib\site-packages\yaml\parser.py:171, in Parser.parse_document_start(self)
#     169 version, tags = self.process_directives()
#     170 if not self.check_token(DocumentStartToken):
# --> 171     raise ParserError(None, None,
#     172             "expected '<document start>', but found %r"
#     173             % self.peek_token().id,
#     174             self.peek_token().start_mark)
#     175 token = self.get_token()
#     176 end_mark = token.end_mark
#
# ParserError: expected '<document start>', but found '<scalar>'
#   in "data\desktop.ini", line 2, column 1

# %%
backup = final_df.copy()

# %%
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Peshawar Zalmi', 'd...                0.9
# 0   [{'1st innings': {'team': 'Quetta Gladiators',...                0.9
# 0   [{'1st innings': {'team': 'Karachi Kings', 'de...                0.9
# 0   [{'1st innings': {'team': 'Islamabad United', ...                0.9
# 0   [{'1st innings': {'team': 'Karachi Kings', 'de...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Lahore Qalandars', ...                0.9
# 0   [{'1st innings': {'team': 'Quetta Gladiators',...                0.9
# 0   [{'1st innings': {'team': 'Karachi Kings', 'de...                0.9
# 0   [{'1st innings': {'team': 'Islamabad United', ...                0.9
# 0   [{'1st innings': {'team': 'Quetta Gladiators',...                0.9
#
#    meta.created  meta.revision       info.competition    info.dates  \
# 0    2017-05-04              1  Pakistan Super League  [2017-02-09]
# 0    2017-05-06              2  Pakistan Super League  [2017-02-10]
# 0    2017-05-05              1  Pakistan Super League  [2017-02-10]
# 0    2017-05-06              1  Pakistan Super League  [2017-02-11]
# 0    2017-05-05              2  Pakistan Super League  [2017-02-11]
# ..          ...            ...                    ...           ...
# 0    2020-08-17              1  Pakistan Super League  [2016-02-17]
# 0    2020-08-17              1  Pakistan Super League  [2016-02-19]
# 0    2020-08-17              1  Pakistan Super League  [2016-02-20]
# 0    2020-08-17              1  Pakistan Super League  [2016-02-21]
# 0    2020-08-17              1  Pakistan Super League  [2016-02-23]
#
#    info.gender info.match_type  info.neutral_venue  info.outcome.by.wickets  \
# 0         male             T20                 1.0                      7.0
# 0         male             T20                 1.0                      NaN
# 0         male             T20                 1.0                      7.0
# 0         male             T20                 1.0                      6.0
# 0         male             T20                 1.0                      7.0
# ..         ...             ...                 ...                      ...
# 0         male             T20                 NaN                      5.0
# 0         male             T20                 NaN                      NaN
# 0         male             T20                 NaN                      9.0
# 0         male             T20                 NaN                      NaN
# 0         male             T20                 NaN                      6.0
#
#     ...                             info.teams info.toss.decision  \
# 0   ...     [Islamabad United, Peshawar Zalmi]              field
# 0   ...  [Lahore Qalandars, Quetta Gladiators]              field
# 0   ...        [Karachi Kings, Peshawar Zalmi]              field
# 0   ...   [Islamabad United, Lahore Qalandars]              field
# 0   ...     [Karachi Kings, Quetta Gladiators]              field
# ..  ...                                    ...                ...
# 0   ...   [Lahore Qalandars, Islamabad United]              field
# 0   ...    [Quetta Gladiators, Peshawar Zalmi]              field
# 0   ...      [Karachi Kings, Islamabad United]              field
# 0   ...     [Islamabad United, Peshawar Zalmi]              field
# 0   ...  [Quetta Gladiators, Islamabad United]              field
#
#      info.toss.winner                info.umpires  \
# 0    Islamabad United   [Ahsan Raza, Shozab Raza]
# 0    Lahore Qalandars  [Rashid Riaz, Shozab Raza]
# 0      Peshawar Zalmi  [Ahmed Shahab, Ahsan Raza]
# 0    Lahore Qalandars  [Asif Yaqoob, Shozab Raza]
# 0   Quetta Gladiators    [Aleem Dar, Rashid Riaz]
# ..                ...                         ...
# 0    Islamabad United      [JS Wilson, Aleem Dar]
# 0      Peshawar Zalmi    [Shozab Raza, Aleem Dar]
# 0    Islamabad United     [Aleem Dar, Ahsan Raza]
# 0      Peshawar Zalmi      [JS Wilson, Aleem Dar]
# 0    Islamabad United      [JS Wilson, Aleem Dar]
#
#                              info.venue match_id info.outcome.by.runs  \
# 0   Dubai International Cricket Stadium        1                  NaN
# 0   Dubai International Cricket Stadium        2                  8.0
# 0   Dubai International Cricket Stadium        3                  NaN
# 0   Dubai International Cricket Stadium        4                  NaN
# 0   Dubai International Cricket Stadium        5                  NaN
# ..                                  ...      ...                  ...
# 0   Dubai International Cricket Stadium      142                  NaN
# 0   Dubai International Cricket Stadium      143                  1.0
# 0   Dubai International Cricket Stadium      144                  NaN
# 0   Dubai International Cricket Stadium      145                 50.0
# 0   Dubai International Cricket Stadium      146                  NaN
#
#    info.outcome.result info.city  info.outcome.eliminator
# 0                  NaN       NaN                      NaN
# 0                  NaN       NaN                      NaN
# 0                  NaN       NaN                      NaN
# 0                  NaN       NaN                      NaN
# 0                  NaN       NaN                      NaN
# ..                 ...       ...                      ...
# 0                  NaN       NaN                      NaN
# 0                  NaN       NaN                      NaN
# 0                  NaN       NaN                      NaN
# 0                  NaN       NaN                      NaN
# 0                  NaN       NaN                      NaN
#
# [146 rows x 24 columns]

# %%
final_df['info.city'].unique()
# Out:
# array([nan, 'Lahore', 'Dubai', 'Sharjah', 'Karachi', 'Abu Dhabi',
#        'Multan', 'Rawalpindi'], dtype=object)

# %%
final_df.columns
# Out:
# Index(['innings', 'meta.data_version', 'meta.created', 'meta.revision',
#        'info.competition', 'info.dates', 'info.gender', 'info.match_type',
#        'info.neutral_venue', 'info.outcome.by.wickets', 'info.outcome.method',
#        'info.outcome.winner', 'info.overs', 'info.player_of_match',
#        'info.teams', 'info.toss.decision', 'info.toss.winner', 'info.umpires',
#        'info.venue', 'match_id', 'info.outcome.by.runs', 'info.outcome.result',
#        'info.city', 'info.outcome.eliminator'],
#       dtype='object')

# %%
final_df.drop(columns=[
    'meta.data_version',
    'info.dates',
    'info.gender',
    'info.match_type',
    'meta.created',
    'meta.revision',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df
# Out:
#                                               innings       info.competition  \
# 0   [{'1st innings': {'team': 'Peshawar Zalmi', 'd...  Pakistan Super League
# 0   [{'1st innings': {'team': 'Quetta Gladiators',...  Pakistan Super League
# 0   [{'1st innings': {'team': 'Karachi Kings', 'de...  Pakistan Super League
# 0   [{'1st innings': {'team': 'Islamabad United', ...  Pakistan Super League
# 0   [{'1st innings': {'team': 'Karachi Kings', 'de...  Pakistan Super League
# ..                                                ...                    ...
# 0   [{'1st innings': {'team': 'Lahore Qalandars', ...  Pakistan Super League
# 0   [{'1st innings': {'team': 'Quetta Gladiators',...  Pakistan Super League
# 0   [{'1st innings': {'team': 'Karachi Kings', 'de...  Pakistan Super League
# 0   [{'1st innings': {'team': 'Islamabad United', ...  Pakistan Super League
# 0   [{'1st innings': {'team': 'Quetta Gladiators',...  Pakistan Super League
#
#    info.outcome.winner  info.overs  info.player_of_match  \
# 0     Islamabad United          20           [BJ Haddin]
# 0    Quetta Gladiators          20         [Hassan Khan]
# 0       Peshawar Zalmi          20          [EJG Morgan]
# 0     Lahore Qalandars          20              [JJ Roy]
# 0    Quetta Gladiators          20          [RR Rossouw]
# ..                 ...         ...                   ...
# 0     Islamabad United          20      [Mohammad Irfan]
# 0    Quetta Gladiators          20  [Mohammad Nawaz (3)]
# 0     Islamabad United          20       [Mohammad Sami]
# 0     Islamabad United          20       [Sharjeel Khan]
# 0     Islamabad United          20            [DR Smith]
#
#                                info.teams info.toss.decision  \
# 0      [Islamabad United, Peshawar Zalmi]              field
# 0   [Lahore Qalandars, Quetta Gladiators]              field
# 0         [Karachi Kings, Peshawar Zalmi]              field
# 0    [Islamabad United, Lahore Qalandars]              field
# 0      [Karachi Kings, Quetta Gladiators]              field
# ..                                    ...                ...
# 0    [Lahore Qalandars, Islamabad United]              field
# 0     [Quetta Gladiators, Peshawar Zalmi]              field
# 0       [Karachi Kings, Islamabad United]              field
# 0      [Islamabad United, Peshawar Zalmi]              field
# 0   [Quetta Gladiators, Islamabad United]              field
#
#      info.toss.winner                info.umpires  \
# 0    Islamabad United   [Ahsan Raza, Shozab Raza]
# 0    Lahore Qalandars  [Rashid Riaz, Shozab Raza]
# 0      Peshawar Zalmi  [Ahmed Shahab, Ahsan Raza]
# 0    Lahore Qalandars  [Asif Yaqoob, Shozab Raza]
# 0   Quetta Gladiators    [Aleem Dar, Rashid Riaz]
# ..                ...                         ...
# 0    Islamabad United      [JS Wilson, Aleem Dar]
# 0      Peshawar Zalmi    [Shozab Raza, Aleem Dar]
# 0    Islamabad United     [Aleem Dar, Ahsan Raza]
# 0      Peshawar Zalmi      [JS Wilson, Aleem Dar]
# 0    Islamabad United      [JS Wilson, Aleem Dar]
#
#                              info.venue  match_id info.city
# 0   Dubai International Cricket Stadium         1       NaN
# 0   Dubai International Cricket Stadium         2       NaN
# 0   Dubai International Cricket Stadium         3       NaN
# 0   Dubai International Cricket Stadium         4       NaN
# 0   Dubai International Cricket Stadium         5       NaN
# ..                                  ...       ...       ...
# 0   Dubai International Cricket Stadium       142       NaN
# 0   Dubai International Cricket Stadium       143       NaN
# 0   Dubai International Cricket Stadium       144       NaN
# 0   Dubai International Cricket Stadium       145       NaN
# 0   Dubai International Cricket Stadium       146       NaN
#
# [146 rows x 12 columns]

# %%
final_df.columns
# Out:
# Index(['innings', 'info.competition', 'info.outcome.winner', 'info.overs',
#        'info.player_of_match', 'info.teams', 'info.toss.decision',
#        'info.toss.winner', 'info.umpires', 'info.venue', 'match_id',
#        'info.city'],
#       dtype='object')

# %%
final_df['info.overs'].value_counts()
# Out:
# 20    146
# Name: info.overs, dtype: int64

# %%
import pickle
pickle.dump(final_df,open('psl_dataset_1.pkl','wb'))

# %%
matches = pickle.load(open('psl_dataset_1.pkl','rb'))
#ball by ball data
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'Mohammad Hafeez',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Sharjeel Khan'],
#     'kind': 'caught',
#     'player_out': 'Mohammad Hafeez'}}},
#  {0.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.3: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.4: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.5: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {1.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'extras': {'legbyes': 1},
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {1.5: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {1.6: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {2.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {2.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {2.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.3: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Sami',
#    'extras': {'legbyes': 1},
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {3.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {3.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.6: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'SR Watson',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {4.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'SR Watson',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.3: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {4.4: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.5: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {4.6: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'extras': {'legbyes': 1},
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {5.3: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'extras': {'legbyes': 4},
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 4, 'total': 4}}},
#  {5.4: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.5: {'batsman': 'DJ Malan',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {6.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {6.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.5: {'batsman': 'DJ Malan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.3: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {7.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {7.6: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.2: {'batsman': 'DJ Malan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.3: {'batsman': 'DJ Malan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {8.4: {'batsman': 'DJ Malan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {9.1: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.3: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {9.4: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {9.5: {'batsman': 'DJ Malan',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Imran Khalid',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {10.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {10.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.4: {'batsman': 'DJ Malan',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {10.5: {'batsman': 'DJ Malan',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {10.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'DJ Malan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {11.1: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {11.2: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.3: {'batsman': 'DJ Malan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Imran Khalid'],
#     'kind': 'caught',
#     'player_out': 'DJ Malan'}}},
#  {11.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'SR Watson',
#    'non_striker': 'EJG Morgan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.5: {'batsman': 'EJG Morgan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.6: {'batsman': 'Kamran Akmal',
#    'bowler': 'SR Watson',
#    'non_striker': 'EJG Morgan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.1: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'EJG Morgan',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.2: {'batsman': 'EJG Morgan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.3: {'batsman': 'EJG Morgan',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'EJG Morgan'}}},
#  {12.4: {'batsman': 'Haris Sohail',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {12.6: {'batsman': 'Haris Sohail',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.1: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.3: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {13.4: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.5: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {13.6: {'batsman': 'Haris Sohail',
#    'bowler': 'Amad Butt',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.1: {'batsman': 'Haris Sohail',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.2: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {14.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.4: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {14.5: {'batsman': 'Kamran Akmal',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.6: {'batsman': 'Haris Sohail',
#    'bowler': 'Saeed Ajmal',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.1: {'batsman': 'Haris Sohail',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.2: {'batsman': 'Haris Sohail',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Kamran Akmal',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.3: {'batsman': 'Kamran Akmal',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Misbah-ul-Haq'],
#     'kind': 'caught',
#     'player_out': 'Kamran Akmal'}}},
#  {15.4: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.5: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.6: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.1: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.2: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {16.3: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.4: {'batsman': 'DJG Sammy',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Sharjeel Khan'],
#     'kind': 'caught',
#     'player_out': 'DJG Sammy'}}},
#  {16.5: {'batsman': 'Shahid Afridi',
#    'bowler': 'Mohammad Irfan',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.6: {'batsman': 'Haris Sohail',
#    'bowler': 'Mohammad Irfan',
#    'extras': {'byes': 4},
#    'non_striker': 'Shahid Afridi',
#    'runs': {'batsman': 0, 'extras': 4, 'total': 4}}},
#  {17.1: {'batsman': 'Shahid Afridi',
#    'bowler': 'SR Watson',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {17.2: {'batsman': 'Shahid Afridi',
#    'bowler': 'SR Watson',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.3: {'batsman': 'Haris Sohail',
#    'bowler': 'SR Watson',
#    'non_striker': 'Shahid Afridi',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.4: {'batsman': 'Shahid Afridi',
#    'bowler': 'SR Watson',
#    'extras': {'wides': 1},
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {17.5: {'batsman': 'Shahid Afridi',
#    'bowler': 'SR Watson',
#    'non_striker': 'Haris Sohail',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Misbah-ul-Haq'],
#     'kind': 'caught',
#     'player_out': 'Shahid Afridi'}}},
#  {17.6: {'batsman': 'Haris Sohail',
#    'bowler': 'SR Watson',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['BJ Haddin'],
#     'kind': 'caught',
#     'player_out': 'Haris Sohail'}}},
#  {17.7: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.1: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.2: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.3: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.4: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Iftikhar Ahmed',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.5: {'batsman': 'Iftikhar Ahmed',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['BJ Haddin'],
#     'kind': 'caught',
#     'player_out': 'Iftikhar Ahmed'}}},
#  {18.6: {'batsman': 'CJ Jordan',
#    'bowler': 'Mohammad Sami',
#    'non_striker': 'Hasan Ali',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.1: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Hasan Ali',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {19.2: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Hasan Ali',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.3: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'extras': {'wides': 1},
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {19.4: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {19.5: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'extras': {'wides': 1},
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {19.6: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'extras': {'wides': 1},
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {19.7: {'batsman': 'Hasan Ali',
#    'bowler': 'SR Watson',
#    'non_striker': 'CJ Jordan',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Amad Butt'],
#     'kind': 'caught',
#     'player_out': 'Hasan Ali'}}},
#  {19.8: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Junaid Khan',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {19.9: {'batsman': 'CJ Jordan',
#    'bowler': 'SR Watson',
#    'non_striker': 'Junaid Khan',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}]

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)

# %%
delivery_df
# Out:
#      match_id                                  teams       batting_team  ball  \
# 0           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.1
# 1           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.2
# 2           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.3
# 3           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.4
# 4           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.5
# ..        ...                                    ...                ...   ...
# 115       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.2
# 116       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.3
# 117       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.4
# 118       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.5
# 119       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.6
#
#              batsman          bowler  runs player_dismissed city  \
# 0    Mohammad Hafeez  Mohammad Irfan     0  Mohammad Hafeez  NaN
# 1       Kamran Akmal  Mohammad Irfan     1                0  NaN
# 2           DJ Malan  Mohammad Irfan     0                0  NaN
# 3           DJ Malan  Mohammad Irfan     0                0  NaN
# 4           DJ Malan  Mohammad Irfan     0                0  NaN
# ..               ...             ...   ...              ...  ...
# 115        Anwar Ali      AD Russell     6                0  NaN
# 116        Anwar Ali      AD Russell     2                0  NaN
# 117        Anwar Ali      AD Russell     0        Anwar Ali  NaN
# 118       GD Elliott      AD Russell     0                0  NaN
# 119       GD Elliott      AD Russell     6                0  NaN
#
#                                    venue
# 0    Dubai International Cricket Stadium
# 1    Dubai International Cricket Stadium
# 2    Dubai International Cricket Stadium
# 3    Dubai International Cricket Stadium
# 4    Dubai International Cricket Stadium
# ..                                   ...
# 115  Dubai International Cricket Stadium
# 116  Dubai International Cricket Stadium
# 117  Dubai International Cricket Stadium
# 118  Dubai International Cricket Stadium
# 119  Dubai International Cricket Stadium
#
# [17327 rows x 10 columns]

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#      match_id                                  teams       batting_team  ball  \
# 0           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.1
# 1           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.2
# 2           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.3
# 3           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.4
# 4           2     [Islamabad United, Peshawar Zalmi]     Peshawar Zalmi   0.5
# ..        ...                                    ...                ...   ...
# 115       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.2
# 116       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.3
# 117       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.4
# 118       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.5
# 119       147  [Quetta Gladiators, Islamabad United]  Quetta Gladiators  19.6
#
#              batsman          bowler  runs player_dismissed city  \
# 0    Mohammad Hafeez  Mohammad Irfan     0  Mohammad Hafeez  NaN
# 1       Kamran Akmal  Mohammad Irfan     1                0  NaN
# 2           DJ Malan  Mohammad Irfan     0                0  NaN
# 3           DJ Malan  Mohammad Irfan     0                0  NaN
# 4           DJ Malan  Mohammad Irfan     0                0  NaN
# ..               ...             ...   ...              ...  ...
# 115        Anwar Ali      AD Russell     6                0  NaN
# 116        Anwar Ali      AD Russell     2                0  NaN
# 117        Anwar Ali      AD Russell     0        Anwar Ali  NaN
# 118       GD Elliott      AD Russell     0                0  NaN
# 119       GD Elliott      AD Russell     6                0  NaN
#
#                                    venue      bowling_team
# 0    Dubai International Cricket Stadium  Islamabad United
# 1    Dubai International Cricket Stadium  Islamabad United
# 2    Dubai International Cricket Stadium  Islamabad United
# 3    Dubai International Cricket Stadium  Islamabad United
# 4    Dubai International Cricket Stadium  Islamabad United
# ..                                   ...               ...
# 115  Dubai International Cricket Stadium  Islamabad United
# 116  Dubai International Cricket Stadium  Islamabad United
# 117  Dubai International Cricket Stadium  Islamabad United
# 118  Dubai International Cricket Stadium  Islamabad United
# 119  Dubai International Cricket Stadium  Islamabad United
#
# [17327 rows x 11 columns]

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Peshawar Zalmi', 'Quetta Gladiators', 'Karachi Kings',
#        'Islamabad United', 'Lahore Qalandars', 'Multan Sultans'],
#       dtype=object)

# %%
delivery_df
# Out:
#      match_id       batting_team  ball          batsman          bowler  runs  \
# 0           2     Peshawar Zalmi   0.1  Mohammad Hafeez  Mohammad Irfan     0
# 1           2     Peshawar Zalmi   0.2     Kamran Akmal  Mohammad Irfan     1
# 2           2     Peshawar Zalmi   0.3         DJ Malan  Mohammad Irfan     0
# 3           2     Peshawar Zalmi   0.4         DJ Malan  Mohammad Irfan     0
# 4           2     Peshawar Zalmi   0.5         DJ Malan  Mohammad Irfan     0
# ..        ...                ...   ...              ...             ...   ...
# 115       147  Quetta Gladiators  19.2        Anwar Ali      AD Russell     6
# 116       147  Quetta Gladiators  19.3        Anwar Ali      AD Russell     2
# 117       147  Quetta Gladiators  19.4        Anwar Ali      AD Russell     0
# 118       147  Quetta Gladiators  19.5       GD Elliott      AD Russell     0
# 119       147  Quetta Gladiators  19.6       GD Elliott      AD Russell     6
#
#     player_dismissed city                                venue  \
# 0    Mohammad Hafeez  NaN  Dubai International Cricket Stadium
# 1                  0  NaN  Dubai International Cricket Stadium
# 2                  0  NaN  Dubai International Cricket Stadium
# 3                  0  NaN  Dubai International Cricket Stadium
# 4                  0  NaN  Dubai International Cricket Stadium
# ..               ...  ...                                  ...
# 115                0  NaN  Dubai International Cricket Stadium
# 116                0  NaN  Dubai International Cricket Stadium
# 117        Anwar Ali  NaN  Dubai International Cricket Stadium
# 118                0  NaN  Dubai International Cricket Stadium
# 119                0  NaN  Dubai International Cricket Stadium
#
#          bowling_team
# 0    Islamabad United
# 1    Islamabad United
# 2    Islamabad United
# 3    Islamabad United
# 4    Islamabad United
# ..                ...
# 115  Islamabad United
# 116  Islamabad United
# 117  Islamabad United
# 118  Islamabad United
# 119  Islamabad United
#
# [17327 rows x 10 columns]

# %%
#new dataframe 
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#      match_id       batting_team      bowling_team  ball  runs  \
# 0           2     Peshawar Zalmi  Islamabad United   0.1     0
# 1           2     Peshawar Zalmi  Islamabad United   0.2     1
# 2           2     Peshawar Zalmi  Islamabad United   0.3     0
# 3           2     Peshawar Zalmi  Islamabad United   0.4     0
# 4           2     Peshawar Zalmi  Islamabad United   0.5     0
# ..        ...                ...               ...   ...   ...
# 115       147  Quetta Gladiators  Islamabad United  19.2     6
# 116       147  Quetta Gladiators  Islamabad United  19.3     2
# 117       147  Quetta Gladiators  Islamabad United  19.4     0
# 118       147  Quetta Gladiators  Islamabad United  19.5     0
# 119       147  Quetta Gladiators  Islamabad United  19.6     6
#
#     player_dismissed city                                venue
# 0    Mohammad Hafeez  NaN  Dubai International Cricket Stadium
# 1                  0  NaN  Dubai International Cricket Stadium
# 2                  0  NaN  Dubai International Cricket Stadium
# 3                  0  NaN  Dubai International Cricket Stadium
# 4                  0  NaN  Dubai International Cricket Stadium
# ..               ...  ...                                  ...
# 115                0  NaN  Dubai International Cricket Stadium
# 116                0  NaN  Dubai International Cricket Stadium
# 117        Anwar Ali  NaN  Dubai International Cricket Stadium
# 118                0  NaN  Dubai International Cricket Stadium
# 119                0  NaN  Dubai International Cricket Stadium
#
# [17327 rows x 8 columns]

# %%
pickle.dump(output,open('psl_dataset_2.pkl','wb'))
